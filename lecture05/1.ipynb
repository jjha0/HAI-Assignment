# %%
from PIL import Image
import torch
from torchvision import transforms
import matplotlib.pyplot as plt

image1 = Image.open('image1.jpg')
image2 = Image.open('image2.jpg')

transform = transforms.ToTensor()

image_tensor1 = transform(image1)
image_tensor2 = transform(image2)

plt.imshow(image_tensor1.permute(1, 2, 0))
plt.show()
plt.imshow(image_tensor2.permute(1, 2, 0))
plt.show()

print(image_tensor1.shape)
print(image_tensor1.dtype)
print(image_tensor2.shape)
print(image_tensor2.dtype)

res1 = image_tensor1 + image_tensor2

plt.imshow(res1.permute(1, 2, 0))
plt.show()

res2 = image_tensor1.matmul(image_tensor2.permute(0, 2, 1))

print(f"the matrix multiplication of image1 and image2 is \n{res2}")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..2.0].
# torch.Size([3, 2160, 3840])
# torch.float32
# torch.Size([3, 2160, 3840])
# torch.float32
# the matrix multiplication of image1 and image2 is
# tensor([[[ 108.4094,  108.3441,  108.7153,  ...,  239.3064,  240.7144,
#            237.8912],
#          [ 108.4799,  108.4241,  108.7984,  ...,  239.3898,  240.9665,
#            237.9869],
#          [ 108.4600,  108.3913,  108.7731,  ...,  239.3233,  241.0564,
#            238.0117],
#          ...,
#          [ 215.1334,  214.5983,  215.7672,  ...,  486.7040,  491.3197,
#            486.3578],
#          [ 214.2550,  213.7508,  214.8878,  ...,  486.2138,  490.6421,
#            485.5606],
#          [ 213.9234,  213.4560,  214.5743,  ...,  486.4620,  490.6398,
#            485.2379]],
#
#         [[ 553.1014,  552.9642,  553.9352,  ...,  359.2321,  361.3167,
#            357.6304],
#          [ 553.0989,  552.9681,  553.9483,  ...,  359.2773,  361.5732,
#            357.7297],
#          [ 553.0525,  552.9166,  553.9069,  ...,  359.3306,  361.8190,
#            357.8684],
#          ...,
#          [ 798.1749,  797.7130,  798.9771,  ...,  518.1975,  521.8011,
#            515.5891],
#          [ 796.3698,  795.9509,  797.2028,  ...,  517.3162,  520.8098,
#            514.5014],
#          [ 795.6405,  795.2403,  796.4662,  ...,  517.1736,  520.4594,
#            513.8917]],
#
#         [[1164.2690, 1164.2344, 1165.6138,  ...,  594.0555,  597.7307,
#            594.6283],
#          [1163.7942, 1163.7610, 1165.1459,  ...,  593.7692,  597.6650,
#            594.3822],
#          [1163.1324, 1163.0850, 1164.4734,  ...,  593.3658,  597.4781,
#            594.0311],
#          ...,
#          [1186.0791, 1185.9644, 1187.2751,  ...,  608.9232,  612.1675,
#            608.0483],
#          [1183.8806, 1183.8041, 1185.1072,  ...,  608.1343,  611.2731,
#            607.0344],
#          [1182.9282, 1182.8745, 1184.1548,  ...,  607.9470,  610.8582,
#            606.3558]]])
